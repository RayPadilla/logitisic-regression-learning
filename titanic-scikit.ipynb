# %%
# Logistic Regression with Scikit-learn
import pandas as pd

df1 = pd.read_csv('datasets/titanic/train.csv')
test_data = pd.read_csv('datasets/titanic/test.csv')
X_test = pd.get_dummies(test_data[features])

x_train = pd.get_dummies(df1[['Pclass', 'Sex', 'SibSp', 'Parch']])
y_train = df1['Survived']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)

model = LogisticRegression()
model.fit(x_train_scaled, y_train)

y_pred = model.predict(x_train_scaled)
score = model.score(x_train_scaled, y_train)
weights = model.coef_
bias = model.intercept_

print('Weights:', weights)
print('Bias:', bias)
print('Score:', score)
print(classification_report(y_train, model.predict(x_train_scaled)))

X_test_scaled = scaler.transform(X_test)
test_pred = model.predict(X_test_scaled)


output = pd.DataFrame({'PassengerId': test_data.PassengerId, 'Survived': test_pred})
output.to_csv('submission.csv', index=False)
# Out:
# Weights: [[-0.7774623  -0.25413021 -0.03974675  0.65605294 -0.65605294]]
# Bias: [-0.63719681]
# Score: 0.8002244668911336
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84       549
#            1       0.78      0.67      0.72       342
#
#     accuracy                           0.80       891
#    macro avg       0.79      0.78      0.78       891
# weighted avg       0.80      0.80      0.80       891
